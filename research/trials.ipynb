# %%
import os
from google.colab import drive

drive.mount('/content/drive')

folder_path = '/content/drive/MyDrive/Weekly Projects/Week 2 - RAG Chatbot with Conversation History'

if not os.path.exists(folder_path):
  try:
    os.makedirs(folder_path, exist_ok=True)
    print(f'Folder {folder_path} created successfully.')
  except OSError as e:
    print(f'Error creating folder {folder_path} : {e}')
else:
  print(f'The folder path already exists.\nChanging current working directory')

if os.path.exists(folder_path):
  os.chdir(folder_path)
  print(f'Current working directory changed to: {os.getcwd()}')
# Out:
# Mounted at /content/drive
# The folder path already exists.
# Changing current working directory
# Current working directory changed to: /content/drive/MyDrive/Weekly Projects/Week 2 - RAG Chatbot with Conversation History

# %% [markdown]
# # Github

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   requirements.txt
# 	modified:   setup.py

# %%
# !git add .

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

username = "TheLLmjourney"  # Replace with your GitHub username
email = "atharvyeram11@gmail.com"  # Replace with your GitHub email
# !git config --global user.name "{username}"
# !git config --global user.email "{email}"

GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')
repo_url =  f"https://oauth2:{GITHUB_TOKEN}@github.com/TheLLmjourney/rag_chatbot.git"

# !git remote set-url origin {repo_url}

# %%
# !git commit -m 'Setup and requirements' # change this
# Out:
# [main b19fac7] Setup and requirements
#  2 files changed, 19 insertions(+), 1 deletion(-)

# %%
# !git push origin main

# !git status
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 585 bytes | 65.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/TheLLmjourney/rag_chatbot.git
#    085c311..b19fac7  main -> main
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # Continue

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/drive/MyDrive/Weekly%20Projects/Week%202%20-%20RAG%20Chatbot%20with%20Conversation%20History/rag_chatbot (from -r requirements.txt (line 9))
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: rag_chatbot
#     Found existing installation: rag_chatbot 0.1
#     Uninstalling rag_chatbot-0.1:
#       Successfully uninstalled rag_chatbot-0.1
#   Running setup.py develop for rag_chatbot
# ...

# %%
os.chdir('/content/drive/MyDrive/Weekly Projects/Week 2 - RAG Chatbot with Conversation History/rag_chatbot')

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.9.0
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.12.14
# aiosignal                             1.4.0
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.2
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# anywidget                             0.9.18
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  21.2.0
# array_record                          0.7.2
# arviz                                 0.22.0
# ...
